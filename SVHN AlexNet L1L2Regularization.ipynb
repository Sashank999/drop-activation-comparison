# %% [markdown]
# # Import libraries

# %%
# %matplotlib inline

import os
import sys
import shutil
print("Python:", sys.version)

import tensorflow as tf
print("TensorFlow version:", tf.__version__)
print("Keras version:", tf.keras.__version__)

import tensorflow.keras as keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, BatchNormalization, Dropout, Dense, Layer
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.callbacks import ModelCheckpoint

import numpy as np
print("NumPy version:", np.__version__)

import scipy
from scipy.io import loadmat
print("SciPy version:", scipy.__version__)

import matplotlib
import matplotlib.pyplot as plt
print("Matplotlib version:", matplotlib.__version__)

import sklearn
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
print("scikit-learn version:", sklearn.__version__)

np.random.seed(99)
tf.random.set_seed(99)
# Out:
# Python: 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
# TensorFlow version: 2.18.0
# Keras version: 3.8.0
# NumPy version: 1.26.4
# SciPy version: 1.13.1
# Matplotlib version: 3.10.0
# scikit-learn version: 1.6.1

# %% [markdown]
# # Download and load the SVHN dataset

# %%
TRAIN_DATASET_PATH = "dataset/train_32x32.mat"
TEST_DATASET_PATH = "dataset/test_32x32.mat"

# %%
if not os.path.isdir("dataset"):
    os.makedirs("dataset")

if not os.path.isfile(TRAIN_DATASET_PATH):
    download_location = tf.keras.utils.get_file(origin=r"http://ufldl.stanford.edu/housenumbers/train_32x32.mat")
    shutil.move(download_location, TRAIN_DATASET_PATH)

if not os.path.isfile(TEST_DATASET_PATH):
    download_location = tf.keras.utils.get_file(origin=r"http://ufldl.stanford.edu/housenumbers/test_32x32.mat")
    shutil.move(download_location, TEST_DATASET_PATH)

# %%
train_dataset = loadmat(TRAIN_DATASET_PATH)
X_train = train_dataset["X"]
y_train = train_dataset["y"]
X_train = X_train.astype("float") / 255
X_train = np.moveaxis(X_train, -1, 0)

y_train[np.where(y_train == 10)] = 0
y_train = keras.utils.to_categorical(y_train, 10)

# %%
X_train.shape
# Out:
# (73257, 32, 32, 3)

# %%
y_train.shape
# Out:
# (73257, 10)

# %%
test_dataset = loadmat(TEST_DATASET_PATH)
X_test = test_dataset["X"]
y_test = test_dataset["y"]
X_test = X_test.astype("float") / 255
X_test = np.moveaxis(X_test, -1, 0)

y_test[np.where(y_test == 10)] = 0
y_test = keras.utils.to_categorical(y_test, 10)

# %%
X_test.shape
# Out:
# (26032, 32, 32, 3)

# %%
y_test.shape
# Out:
# (26032, 10)

# %% [markdown]
# # Create model

# %%
# AlexNet architecture

model = keras.Sequential([
    Input(shape=(32, 32, 3)),

    Conv2D(32, (5, 5), activation="relu", padding="valid"),
    MaxPooling2D((2,2)),
    # BatchNormalization(),

    Conv2D(32, (3, 3), activation="relu", padding="valid"),
    MaxPooling2D((2,2)),
    # BatchNormalization(),

    Conv2D(64, (3, 3), activation="relu", padding="valid"),
    Conv2D(64, (1, 1), activation="relu", padding="valid"),
    Conv2D(128, (1, 1), activation="relu", padding="valid"),
    MaxPooling2D((2,2)),

    Flatten(),
    Dense(256, activation="relu", kernel_regularizer="l1l2"),
    Dense(128, activation="relu", kernel_regularizer="l1l2"),
    Dense(64, activation="relu", kernel_regularizer="l1l2"),
    # Dropout(0.5),

    Dense(10, activation="softmax")
])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 28, 28, 32)          │           2,432 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 12, 12, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 6, 6, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 4, 4, 64)            │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 4, 4, 64)            │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 4, 4, 128)           │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 2, 2, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 215,786 (842.91 KB)
#  Trainable params: 215,786 (842.91 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Train the model

# %%
best_model_saving_callback = ModelCheckpoint(filepath="Best Model.keras", monitor="val_accuracy", mode="max", save_best_only=True)

# %%
model.compile(loss=CategoricalCrossentropy(), optimizer=Adam(), metrics=["accuracy"])

# %%
history = model.fit(X_train, y_train, validation_split=0.2, epochs=20, callbacks=[best_model_saving_callback])
# Out:
# Epoch 1/20
# 1832/1832 ━━━━━━━━━━━━━━━━━━━━ 22s 8ms/step - accuracy: 0.4069 - loss: 1.6849 - val_accuracy: 0.8139 - val_loss: 0.6119
# Epoch 2/20
# 1832/1832 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8247 - loss: 0.5617 - val_accuracy: 0.8536 - val_loss: 0.4772
# Epoch 3/20
# 1832/1832 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8595 - loss: 0.4540 - val_accuracy: 0.8510 - val_loss: 0.5232
# Epoch 4/20
# 1832/1832 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8787 - loss: 0.3991 - val_accuracy: 0.8711 - val_loss: 0.4413
# Epoch 5/20
# 1832/1832 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8889 - loss: 0.3575 - val_accuracy: 0.8798 - val_loss: 0.4026
# Epoch 6/20
# 1832/1832 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9017 - loss: 0.3220 - val_accuracy: 0.8830 - val_loss: 0.3994
# Epoch 7/20
# 1832/1832 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9099 - loss: 0.2956 - val_accuracy: 0.8896 - val_loss: 0.3875
# Epoch 8/20
# 1832/1832 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9160 - loss: 0.2725 - val_accuracy: 0.8915 - val_loss: 0.3826
# Epoch 9/20
# 1832/1832 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9235 - loss: 0.2523 - val_accuracy: 0.8905 - val_loss: 0.3952
# Epoch 10/20
# 1832/1832 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9270 - loss: 0.2383 - val_accuracy: 0.8919 - val_loss: 0.4082
# Epoch 11/20
# 1832/1832 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9312 - loss: 0.2220 - val_accuracy: 0.8933 - val_loss: 0.4097
# Epoch 12/20
# 1832/1832 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9357 - loss: 0.2097 - val_accuracy: 0.8933 - val_loss: 0.4185
# Epoch 13/20
# 1832/1832 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9389 - loss: 0.1989 - val_accuracy: 0.8875 - val_loss: 0.4384
# Epoch 14/20
# 1832/1832 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9411 - loss: 0.1871 - val_accuracy: 0.8913 - val_loss: 0.4557
# Epoch 15/20
# 1832/1832 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9431 - loss: 0.1811 - val_accuracy: 0.8955 - val_loss: 0.4424
# Epoch 16/20
# 1832/1832 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9462 - loss: 0.1723 - val_accuracy: 0.8945 - val_loss: 0.4648
# Epoch 17/20
# 1832/1832 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9487 - loss: 0.1680 - val_accuracy: 0.8835 - val_loss: 0.4813
# Epoch 18/20
# 1832/1832 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9484 - loss: 0.1612 - val_accuracy: 0.8852 - val_loss: 0.5098
# Epoch 19/20
# 1832/1832 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9516 - loss: 0.1549 - val_accuracy: 0.8811 - val_loss: 0.5360
# Epoch 20/20
# 1832/1832 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9533 - loss: 0.1500 - val_accuracy: 0.8849 - val_loss: 0.5194

# %%
# Save fully trained model and load the best model for further evaluation cells.
fully_trained_model = model
model = tf.keras.models.load_model("Best Model.keras")

# %%
fig, axis = plt.subplots(1, 2)

axis[0].plot(history.history["accuracy"])
axis[0].plot(history.history["val_accuracy"])
axis[0].set_title("Model Accuracy")
axis[0].set_ylabel("Accuracy")
axis[0].set_xlabel("Epoch")
axis[0].legend(["Train", "Test"], loc="upper left")

# summarize history for loss
axis[1].plot(history.history["loss"])
axis[1].plot(history.history["val_loss"])
axis[1].set_title("Model Loss")
axis[1].set_ylabel("Loss")
axis[1].set_xlabel("Epoch")
axis[1].legend(["Train", "Test"], loc="upper left")

fig.tight_layout()
plt.show()

# %% [markdown]
# # Model Accuracy

# %%
d = model.evaluate(X_test, y_test, return_dict=True)
model_accuracy_truncated = int(d["accuracy"] * 100 * 100) / 100
d
# Out:
# 814/814 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8907 - loss: 0.4945
# {'accuracy': 0.8925937414169312, 'loss': 0.4813894033432007}

# %%
y_pred = model.predict(X_test)
# Out:
# 814/814 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step

# %%
model.compute_metrics(X_test, y_test, y_pred)
# Out:
# {'accuracy': 0.8925937414169312, 'loss': 0.4813894033432007}

# %%
cm = confusion_matrix(np.argmax(y_test, axis=-1), y_pred.argmax(axis=-1), normalize="true")

# %%
ConfusionMatrixDisplay.from_predictions(np.argmax(y_test, axis=-1), y_pred.argmax(axis=-1), normalize="true", values_format=".2f")

# %% [markdown]
# # Save model

# %%
model.save(f"Colab AlexNet L1L2Regularization {model_accuracy_truncated}.keras")

# %%
# Accuracy over 5 runs.
# 89.25
#
#
#
#
# Average: .

# %% [markdown]
# # Load model for inference

# %%
# model = tf.keras.models.load_model("Colab SVHN AlexNet.keras")

# %%
# model.evaluate(X_test, y_test, return_dict=True)
